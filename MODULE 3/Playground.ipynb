# %% [markdown]
# Playground under prompt engineering section
#
#  ![image.png](attachment:22a8bc26-7657-49c9-99ab-9dcbfa88a4d7.png)
#
# ![image.png](attachment:d4389838-00e8-4191-b7f7-512892c934b7.png)
#
# Question: What is the meaning of life
#
# ![image.png](attachment:731ebed5-bb60-4545-8ffd-1ca0c0dd1d54.png)
#
# Question: Where can I learn about philosophy?
#
# ![image.png](attachment:896e57d6-06ca-49ba-95d2-ca4f323a17d4.png)
#
# ![image.png](attachment:f93b9210-2116-4360-9389-3ad338e71c49.png)
#
# System Prompt: You are a pirate from the 1600s
#
# ![image.png](attachment:8f8af1ec-3026-4e6b-bd99-79201be919ec.png)
#
# Turning off streaming
#
# ![image.png](attachment:51636013-2367-4556-91f4-0d753b8b3c09.png)
#
# Running with two repetitions
#
# ![image.png](attachment:b57f2f97-84dc-4a46-8550-aa490a3ec44b.png)
#
# Adding an output schema
#
# ![image.png](attachment:b81044d4-66be-475e-be9e-67a83bf09594.png)
#
# ![image.png](attachment:ac53708d-1f25-4e7c-8afa-930e2cf11c61.png)
#
# Adding a tool
#
# ![image.png](attachment:77d1bce7-ea2e-4dc5-b7fb-eaf9efb34f23.png)
#
# ![image.png](attachment:15dcc42c-fd8f-4ed2-a9d4-981a83cdad06.png)
